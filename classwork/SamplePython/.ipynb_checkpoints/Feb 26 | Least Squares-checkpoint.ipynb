# %%
import numpy as np

x=np.array([1,2,3,4,5])
y=np.array([1.2,2.8,3,6,4.5,5.1])

A=np.vstack([x,np.ones(len(x))]).T

print("x:")
print(x)

print("y:")
print(y)
# Out:
# x:
# [1 2 3 4 5]
# y:
# [1.2 2.8 3.  6.  4.5 5.1]

# %%
m,c=np.linalg.lstsq(A,y,rcond=None)[0]
print(f"Slope: {m}, Intercept: {c}")
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-7-f57edc3002bb> in <module>
# ----> 1 m,c=np.linalg.lstsq(A,y,rcond=None)[0]
#       2 print(f"Slope: {m}, Intercept: {c}")
#
# <__array_function__ internals> in lstsq(*args, **kwargs)
#
# /opt/conda/lib/python3.8/site-packages/numpy/linalg/linalg.py in lstsq(a, b, rcond)
#    2235     m2, n_rhs = b.shape[-2:]
#    2236     if m != m2:
# -> 2237         raise LinAlgError('Incompatible dimensions')
#    2238
#    2239     t, result_t = _commonType(a, b)
#
# LinAlgError: Incompatible dimensions

# %%
import matlib as
